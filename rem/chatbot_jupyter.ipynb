# %%
import nltk
from nltk.chat.util import Chat, reflections

# %%
reflections = {
  "i am"       : "you are",
  "i was"      : "you were",
  "i"          : "you",
  "i'm"        : "you are",
  "i'd"        : "you would",
  "i've"       : "you have",
  "i'll"       : "you will",
  "my"         : "your",
  "you are"    : "I am",
  "you were"   : "I was",
  "you've"     : "I have",
  "you'll"     : "I will",
  "your"       : "my",
  "yours"      : "mine",
  "you"        : "me",
  "me"         : "you"
}

# %%
pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today ?",]
    ],
    [
        r"hi|hey|hello",
        ["Hello", "Hey there",]
    ], 
    [
        r"what is your name ?",
        ["I am a bot created by Analytics Prathmesh. you can call me crazy!",]
    ],
    [
        r"how are you ?",
        ["I'm doing goodnHow about You ?",]
    ],
    [
        r"sorry (.*)",
        ["Its alright","Its OK, never mind",]
    ],
    [
        r"I am fine",
        ["Great to hear that, How can I help you?",]
    ],
    [
        r"i'm (.*) doing good",
        ["Nice to hear that","How can I help you?:)",]
    ],
    [
        r"(.*) age?",
        ["I'm a computer program dudenSeriously you are asking me this?",]
    ],
    [
        r"what (.*) want ?",
        ["Make me an offer I can't refuse",]
    ],
    [
        r"(.*) created ?",
        ["Raghav created me using Python's NLTK library ","top secret ;)",]
    ],
    [
        r"(.*) (location|city) ?",
        ['Indore, Madhya Pradesh',]
    ],
    [
        r"how is weather in (.*)?",
        ["Weather in %1 is awesome like always","Too hot man here in %1","Too cold man here in %1","Never even heard about %1"]
    ],
    [
        r"i work in (.*)?",
        ["%1 is an Amazing company, I have heard about it. But they are in huge loss these days.",]
    ],
    [
        r"(.*)raining in (.*)",
        ["No rain since last week here in %2","Damn its raining too much here in %2"]
    ],
    [
        r"how (.*) health(.*)",
        ["I'm a computer program, so I'm always healthy ",]
    ],
    [
        r"(.*) (sports|game) ?",
        ["I'm a very big fan of Football",]
    ],
    [
        r"who (.*) sportsperson ?",
        ["Messy","Ronaldo","virat"]
    ],
    [
        r"who (.*) (moviestar|actor)?",
        ["Brad Pitt"]
    ],
    [
        r"i am looking for online guides and courses to learn data science, can you suggest?",
        ["Crazy_Tech has many great articles with each step explanation along with code, you can explore"]
    ],
    [
        r"quit",
        ["BBye take care. See you soon :) ","It was nice talking to you. See you soon :)"]
    ],
]

# %%
def chat():
    print("Hi! I am a chatbot created by Analytics Vidhya for your service")
    chat = Chat(pairs, reflections)
    chat.converse()
#initiate the conversation
if __name__ == "__main__":
    chat()
# Out:
# Hi! I am a chatbot created by Analytics Vidhya for your service

# %%
"""
This code is an implementation of a simple chatbot using the NLTK (Natural Language Toolkit) library in Python. Let's go through the code step by step to understand its functionality:

1. Importing the necessary modules:
   - `nltk`: The main module of the NLTK library.
   - `Chat` and `reflections` from `nltk.chat.util`: These are utility classes that provide a framework for creating chatbots and handling pattern matching.

2. Defining reflections:
   - `reflections` is a dictionary that maps personal pronouns and verb forms to their corresponding reflections. It is used to transform user inputs to simulate more natural conversations. For example, if the user says "I am happy," the chatbot will transform it to "You are happy" before generating a response.

3. Defining conversation patterns and responses:
   - `pairs` is a list of conversation patterns and their corresponding responses.
   - Each pattern is a regular expression (regex) string that the user input is matched against.
   - The responses are a list of possible responses that the chatbot can give based on the matched pattern.
   - The patterns and responses are defined as pairs within the `pairs` list.

4. Defining the `chat()` function:
   - This function prints a greeting message and creates an instance of the `Chat` class.
   - The `Chat` class is initialized with the `pairs` list and the `reflections` dictionary.
   - It then starts the conversation loop, where the chatbot waits for user input and generates responses based on the matched pattern.

5. Initiating the conversation:
   - The `if __name__ == "__main__":` block checks if the script is being run directly.
   - If it is, the `chat()` function is called to initiate the conversation with the chatbot.

The chatbot responds to various user inputs and patterns such as greetings, asking for the bot's name, asking about the weather, talking about sports, movies, etc. The chatbot uses pattern matching to identify user intents and generates appropriate responses based on the predefined patterns and responses in the `pairs` list.

Please note that the code assumes you have the NLTK library installed and have downloaded any required datasets or resources. If not, you may need to install NLTK and download the required resources using NLTK's `nltk.download()` function before running the code successfully.
"""
