# %%
import numpy as np
import pandas as pd

# %%
cols = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
data = pd.read_csv('auto.csv',names=cols)

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3                 ?  alfa-romero       gas        std  \
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height
# count  205.000000  205.000000  205.000000  205.000000  205.000000  \
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=205, step=1)

# %%
data.values
# Out:
# array([[3, '?', 'alfa-romero', ..., 21, 27, '13495'],
#        [3, '?', 'alfa-romero', ..., 21, 27, '16500'],
#        [1, '?', 'alfa-romero', ..., 19, 26, '16500'],
#        ...,
#        [-1, '95', 'volvo', ..., 18, 23, '21485'],
#        [-1, '95', 'volvo', ..., 26, 27, '22470'],
#        [-1, '95', 'volvo', ..., 19, 25, '22625']], dtype=object)

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3                 ?  alfa-romero       gas        std          two  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors
# 200         -1                95  volvo       gas        std         four  \
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 200      sedan          rwd           front       109.1  ...          141  \
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm
# ...

# %%
data.copy()
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3                 ?  alfa-romero       gas        std  \
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
data.loc[1::5]
# Out:
#      symboling normalized-losses           make fuel-type aspiration
# 1            3                 ?    alfa-romero       gas        std  \
# 6            1               158           audi       gas        std
# 11           0               192            bmw       gas        std
# 16           0                 ?            bmw       gas        std
# 21           1               118          dodge       gas        std
# 26           1               148          dodge       gas        std
# 31           2               137          honda       gas        std
# 36           0                78          honda       gas        std
# 41           0                85          honda       gas        std
# 46           2                 ?          isuzu       gas        std
# 51           1               104          mazda       gas        std
# 56           3               150          mazda       gas        std
# 61           1               129          mazda       gas        std
# ...

# %%
data.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      symboling normalized-losses         make fuel-type aspiration
# 0            3                 ?  alfa-romero       gas        std  \
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# ...

# %%
data['fuel-type'].value_counts()
# Out:
# fuel-type
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
data.iloc[1::5]
# Out:
#      symboling normalized-losses           make fuel-type aspiration
# 1            3                 ?    alfa-romero       gas        std  \
# 6            1               158           audi       gas        std
# 11           0               192            bmw       gas        std
# 16           0                 ?            bmw       gas        std
# 21           1               118          dodge       gas        std
# 26           1               148          dodge       gas        std
# 31           2               137          honda       gas        std
# 36           0                78          honda       gas        std
# 41           0                85          honda       gas        std
# 46           2                 ?          isuzu       gas        std
# 51           1               104          mazda       gas        std
# 56           3               150          mazda       gas        std
# 61           1               129          mazda       gas        std
# ...

# %%
data["length"].mean()
# Out:
# 174.04926829268288

# %%
data.iloc[1:5]
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 1          3                 ?  alfa-romero       gas        std          two  \
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 1  convertible          rwd           front        88.6  ...          130  \
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg
# 1         mpfi  3.47    2.68               9.0        111      5000       21  \
# ...

# %%
data['wheel-base'].mean()
# Out:
# 98.75658536585367

# %%
data['wheel-base'].median()
# Out:
# 97.0

# %%
data['wheel-base'].mode()
# Out:
# 0    94.5
# Name: wheel-base, dtype: float64

# %%
data = data.replace("?", np.NaN)
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3               NaN  alfa-romero       gas        std          two  \
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors
# 0        False               True  False      False       False         False  \
# 1        False               True  False      False       False         False
# 2        False               True  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data['symboling'].isnull().sum()
# Out:
# 0

# %%
avg = data['normalized-losses'].astype('float').mean()

# %%
avg
# Out:
# 122.0

# %%
avg
# Out:
# 122.0

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3               NaN  alfa-romero       gas        std  \
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
data['normalized-losses'].replace(np.NaN, 122.0, inplace=True)

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3             122.0  alfa-romero       gas        std  \
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
avg1=  data['bore'].astype('float').mean()

# %%
avg1
# Out:
# 3.3297512437810943

# %%
data['bore'].replace(np.NaN, 3.3290, inplace=True)

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3             122.0  alfa-romero       gas        std  \
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
avg2 = data['stroke'].astype('float').mean()
avg2
# Out:
# 3.255422885572139

# %%
data['stroke'].replace(np.NaN, 3.2583, inplace=True)
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3             122.0  alfa-romero       gas        std  \
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
avg3 = data['horsepower'].astype('float').mean()

# %%
avg3
# Out:
# 104.25615763546799

# %%
data['horsepower'].replace(np.NaN, 104.25, inplace=True)

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3             122.0  alfa-romero       gas        std          two  \
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
avg4 = data['peak-rpm'].astype('float').mean()
avg4
# Out:
# 5125.369458128079

# %%
data['peak-rpm'].replace(np.NaN, 5125.36, inplace=True)

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3             122.0  alfa-romero       gas        std  \
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
avg5 = data['price'].astype('float').mean()
avg5
# Out:
# 13207.129353233831

# %%
data['price'].replace(np.NaN, 13207, inplace=True)

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors
# 0          3             122.0  alfa-romero       gas        std          two  \
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size
# 0  convertible          rwd           front        88.6  ...          130  \
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3             122.0  alfa-romero       gas        std  \
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
data['num-of-doors'].replace(np.NaN, 'four', inplace=True)

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration
# 0            3             122.0  alfa-romero       gas        std  \
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# 0            two  convertible          rwd           front        88.6  ...  \
# ...

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data['normalized-losses']=data['normalized-losses'].astype('float')

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg             float64
# highway-mpg          float64
# price                 object
# dtype: object

# %%
data['highway-mpg']=235/data['highway-mpg']
data['city-mpg']=235/data['city-mpg']

# %%
data
# Out:
#      symboling  normalized-losses         make fuel-type aspiration
# 0            3              122.0  alfa-romero       gas        std  \
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# ...

# %%
data['height']=(data['height'] - data['height'].min())/(data['height'].max() - data['height'].min())

# %%
data['height']
# Out:
# 0      0.083333
# 1      0.083333
# 2      0.383333
# 3      0.541667
# 4      0.541667
#          ...
# 200    0.641667
# 201    0.641667
# 202    0.641667
# 203    0.641667
# 204    0.641667
# Name: height, Length: 205, dtype: float64

# %%
data['length']=data['length']/data['length'].max()

# %%
data['length']
# Out:
# 0      0.811148
# 1      0.811148
# 2      0.822681
# 3      0.848630
# 4      0.848630
#          ...
# 200    0.907256
# 201    0.907256
# 202    0.907256
# 203    0.907256
# 204    0.907256
# Name: length, Length: 205, dtype: float64

# %%
data['width']=data['width']/data['width'].max()

# %%
data['width']
# Out:
# 0      0.886584
# 1      0.886584
# 2      0.905947
# 3      0.915629
# 4      0.918396
#          ...
# 200    0.952974
# 201    0.951591
# 202    0.952974
# 203    0.952974
# 204    0.952974
# Name: width, Length: 205, dtype: float64

# %%
data
# Out:
#      symboling  normalized-losses         make fuel-type aspiration
# 0            3              122.0  alfa-romero       gas        std  \
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...
# ...
