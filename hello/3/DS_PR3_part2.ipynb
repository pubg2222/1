# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Anti.csv")

# %%
data
# Out:
#     ANTI_A  ANTI_B    V1
# 0     2.77    98.1   6.0
# 1     9.79    16.8   6.7
# 2     9.29    13.6   7.5
# 3     3.41     1.6   7.6
# 4     9.83    55.3   8.4
# 5     5.76    94.4   9.3
# 6     2.73    67.2   9.4
# 7     0.17    41.9   9.6
# 8     7.50    22.7  10.6
# 9     0.21    39.6  11.2
# 10    0.66    61.6  11.3
# 11    2.84    78.9  11.5
# 12    7.90    15.5  11.5
# 13    2.00    93.3  11.9
# 14    5.07    87.9  13.0
# 15    2.14    85.0  13.8
# 16    9.94    16.4  14.1
# 17    7.21    20.6  14.9
# 18    4.41     4.8  15.2
# 19    8.70    48.3  15.8
# 20    3.05    86.3  16.5
# 21    9.34    52.6  17.7
# 22    7.36    13.0  21.4
# 23    7.79    61.4  55.5
# 24    4.24    53.3  60.0
# 25    0.63    11.3  61.4
# 26    1.43    26.2  62.1
# 27    1.44    32.9  64.9
# 28    7.34    83.4  64.9
# 29    1.74    12.7  69.0
# 30    6.12    35.4  70.1
# 31    7.59    76.7  73.4
# 32    7.31    58.4  74.9
# 33    7.17    86.9  76.8
# 34    2.99    20.6  77.0
# 35    2.84    33.6  77.9
# 36    0.67     9.2  80.1
# 37    8.62    78.9  81.2
# 38    7.44    98.8  83.8
# 39    7.21    88.0  90.7

# %%
bins = np.linspace(min(data['V1']), max(data['V1']), 6)
bins
# Out:
# array([ 6.  , 22.94, 39.88, 56.82, 73.76, 90.7 ])

# %%
group_names = ["b1", "b2", "b3", "b4", "b5"]

# %%
data['Eqwidth_bin'] = pd.cut(data['V1'], bins, labels = group_names, include_lowest = True)

# %%
data
# Out:
#     ANTI_A  ANTI_B    V1 Eqwidth_bin
# 0     2.77    98.1   6.0          b1
# 1     9.79    16.8   6.7          b1
# 2     9.29    13.6   7.5          b1
# 3     3.41     1.6   7.6          b1
# 4     9.83    55.3   8.4          b1
# 5     5.76    94.4   9.3          b1
# 6     2.73    67.2   9.4          b1
# 7     0.17    41.9   9.6          b1
# 8     7.50    22.7  10.6          b1
# 9     0.21    39.6  11.2          b1
# 10    0.66    61.6  11.3          b1
# 11    2.84    78.9  11.5          b1
# 12    7.90    15.5  11.5          b1
# 13    2.00    93.3  11.9          b1
# 14    5.07    87.9  13.0          b1
# 15    2.14    85.0  13.8          b1
# 16    9.94    16.4  14.1          b1
# 17    7.21    20.6  14.9          b1
# 18    4.41     4.8  15.2          b1
# 19    8.70    48.3  15.8          b1
# 20    3.05    86.3  16.5          b1
# 21    9.34    52.6  17.7          b1
# 22    7.36    13.0  21.4          b1
# 23    7.79    61.4  55.5          b3
# 24    4.24    53.3  60.0          b4
# 25    0.63    11.3  61.4          b4
# 26    1.43    26.2  62.1          b4
# 27    1.44    32.9  64.9          b4
# 28    7.34    83.4  64.9          b4
# 29    1.74    12.7  69.0          b4
# 30    6.12    35.4  70.1          b4
# 31    7.59    76.7  73.4          b4
# 32    7.31    58.4  74.9          b5
# 33    7.17    86.9  76.8          b5
# 34    2.99    20.6  77.0          b5
# 35    2.84    33.6  77.9          b5
# 36    0.67     9.2  80.1          b5
# 37    8.62    78.9  81.2          b5
# 38    7.44    98.8  83.8          b5
# 39    7.21    88.0  90.7          b5

# %%
data['Eqfreq_bins'] = pd.qcut(data['V1'], q=5, labels = ['f1', 'f2', 'f3', 'f4', 'f5'])

# %%
data
# Out:
#     ANTI_A  ANTI_B    V1 Eqwidth_bin Eqfreq_bins
# 0     2.77    98.1   6.0          b1          f1
# 1     9.79    16.8   6.7          b1          f1
# 2     9.29    13.6   7.5          b1          f1
# 3     3.41     1.6   7.6          b1          f1
# 4     9.83    55.3   8.4          b1          f1
# 5     5.76    94.4   9.3          b1          f1
# 6     2.73    67.2   9.4          b1          f1
# 7     0.17    41.9   9.6          b1          f1
# 8     7.50    22.7  10.6          b1          f2
# 9     0.21    39.6  11.2          b1          f2
# 10    0.66    61.6  11.3          b1          f2
# 11    2.84    78.9  11.5          b1          f2
# 12    7.90    15.5  11.5          b1          f2
# 13    2.00    93.3  11.9          b1          f2
# 14    5.07    87.9  13.0          b1          f2
# 15    2.14    85.0  13.8          b1          f2
# 16    9.94    16.4  14.1          b1          f3
# 17    7.21    20.6  14.9          b1          f3
# 18    4.41     4.8  15.2          b1          f3
# 19    8.70    48.3  15.8          b1          f3
# 20    3.05    86.3  16.5          b1          f3
# 21    9.34    52.6  17.7          b1          f3
# 22    7.36    13.0  21.4          b1          f3
# 23    7.79    61.4  55.5          b3          f3
# 24    4.24    53.3  60.0          b4          f4
# 25    0.63    11.3  61.4          b4          f4
# 26    1.43    26.2  62.1          b4          f4
# 27    1.44    32.9  64.9          b4          f4
# 28    7.34    83.4  64.9          b4          f4
# 29    1.74    12.7  69.0          b4          f4
# 30    6.12    35.4  70.1          b4          f4
# 31    7.59    76.7  73.4          b4          f4
# 32    7.31    58.4  74.9          b5          f5
# 33    7.17    86.9  76.8          b5          f5
# 34    2.99    20.6  77.0          b5          f5
# 35    2.84    33.6  77.9          b5          f5
# 36    0.67     9.2  80.1          b5          f5
# 37    8.62    78.9  81.2          b5          f5
# 38    7.44    98.8  83.8          b5          f5
# 39    7.21    88.0  90.7          b5          f5

# %%
condition1 = data['Eqwidth_bin'] == 'b1'
condition2 = data['Eqwidth_bin'] == 'b5'

# %%
group1 = data[condition1].groupby('Eqwidth_bin')['V1'].transform(list)

# %%
group2 = data[condition2].groupby('Eqwidth_bin')['V1'].transform(list)

# %%
data['group1'] = group1
data['group2'] = group2

# %%
data
# Out:
#     ANTI_A  ANTI_B    V1 Eqwidth_bin Eqfreq_bins  group1  group2
# 0     2.77    98.1   6.0          b1          f1     6.0     NaN
# 1     9.79    16.8   6.7          b1          f1     6.7     NaN
# 2     9.29    13.6   7.5          b1          f1     7.5     NaN
# 3     3.41     1.6   7.6          b1          f1     7.6     NaN
# 4     9.83    55.3   8.4          b1          f1     8.4     NaN
# 5     5.76    94.4   9.3          b1          f1     9.3     NaN
# 6     2.73    67.2   9.4          b1          f1     9.4     NaN
# 7     0.17    41.9   9.6          b1          f1     9.6     NaN
# 8     7.50    22.7  10.6          b1          f2    10.6     NaN
# 9     0.21    39.6  11.2          b1          f2    11.2     NaN
# 10    0.66    61.6  11.3          b1          f2    11.3     NaN
# 11    2.84    78.9  11.5          b1          f2    11.5     NaN
# 12    7.90    15.5  11.5          b1          f2    11.5     NaN
# 13    2.00    93.3  11.9          b1          f2    11.9     NaN
# 14    5.07    87.9  13.0          b1          f2    13.0     NaN
# 15    2.14    85.0  13.8          b1          f2    13.8     NaN
# 16    9.94    16.4  14.1          b1          f3    14.1     NaN
# 17    7.21    20.6  14.9          b1          f3    14.9     NaN
# 18    4.41     4.8  15.2          b1          f3    15.2     NaN
# 19    8.70    48.3  15.8          b1          f3    15.8     NaN
# 20    3.05    86.3  16.5          b1          f3    16.5     NaN
# 21    9.34    52.6  17.7          b1          f3    17.7     NaN
# 22    7.36    13.0  21.4          b1          f3    21.4     NaN
# 23    7.79    61.4  55.5          b3          f3     NaN     NaN
# 24    4.24    53.3  60.0          b4          f4     NaN     NaN
# 25    0.63    11.3  61.4          b4          f4     NaN     NaN
# 26    1.43    26.2  62.1          b4          f4     NaN     NaN
# 27    1.44    32.9  64.9          b4          f4     NaN     NaN
# 28    7.34    83.4  64.9          b4          f4     NaN     NaN
# 29    1.74    12.7  69.0          b4          f4     NaN     NaN
# 30    6.12    35.4  70.1          b4          f4     NaN     NaN
# 31    7.59    76.7  73.4          b4          f4     NaN     NaN
# 32    7.31    58.4  74.9          b5          f5     NaN    74.9
# 33    7.17    86.9  76.8          b5          f5     NaN    76.8
# 34    2.99    20.6  77.0          b5          f5     NaN    77.0
# 35    2.84    33.6  77.9          b5          f5     NaN    77.9
# 36    0.67     9.2  80.1          b5          f5     NaN    80.1
# 37    8.62    78.9  81.2          b5          f5     NaN    81.2
# 38    7.44    98.8  83.8          b5          f5     NaN    83.8
# 39    7.21    88.0  90.7          b5          f5     NaN    90.7

# %%
group1_mean = data['group1'].mean()
group1_median = data['group1'].median()
group1_q1 = data['group1'].quantile(0.25)
group1_q3 = data['group1'].quantile()
group1_std = data['group1'].std()

print(group1_mean)
print(group1_median)
print(group1_q1)
print(group1_q3)
print(group1_std)
# Out:
# 11.952173913043477
# 11.5
# 9.350000000000001
# 11.5
# 3.8308401126096934

# %%
group2_mean = data['group2'].mean()
group2_median = data['group2'].median()
group2_q1 = data['group2'].quantile(0.25)
group2_q3 = data['group2'].quantile()
group2_std = data['group2'].std()

print(group2_mean)
print(group2_median)
print(group2_q1)
print(group2_q3)
print(group2_std)
# Out:
# 80.30000000000001
# 79.0
# 76.95
# 79.0
# 5.0613380500755785

# %%
fig, ax = plt.subplots()
ax.boxplot([data[data['Eqwidth_bin'] == 'b1']['group1']])
ax.set_xticklabels(['b1'])

ax.set_title('Boxplot of group1')
ax.set_xlabel('Eqwidth_bin')
ax.set_ylabel('Virus measure for group1')

plt.show()

# %%
fig, ax = plt.subplots()
ax.boxplot([data[data['Eqwidth_bin'] == 'b5']['group2']])
ax.set_xticklabels(['b5'])

ax.set_title('Boxplot of group2')
ax.set_xlabel('Eqwidth_bin')
ax.set_ylabel('Virus measure for group2')

plt.show()

# %%
data.loc[data['Eqwidth_bin'] == 'b1', 'normalized_antiA_g1'] = (data.loc[data['Eqwidth_bin'] == 'b1', 'ANTI_A'] -  data.loc[data['Eqwidth_bin'] == 'b1', 'ANTI_A'].min())/ (data.loc[data['Eqwidth_bin'] == 'b1', 'ANTI_A'].max()-data.loc[data['Eqwidth_bin'] == 'b1', 'ANTI_A'].min())

# %%
data['normalized_antiA_g1']
# Out:
# 0     0.266121
# 1     0.984647
# 2     0.933470
# 3     0.331627
# 4     0.988741
# 5     0.572160
# 6     0.262027
# 7     0.000000
# 8     0.750256
# 9     0.004094
# 10    0.050154
# 11    0.273286
# 12    0.791198
# 13    0.187308
# 14    0.501535
# 15    0.201638
# 16    1.000000
# 17    0.720573
# 18    0.433982
# 19    0.873081
# 20    0.294780
# 21    0.938588
# 22    0.735926
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# Name: normalized_antiA_g1, dtype: float64

# %%
data.loc[data['Eqwidth_bin'] == 'b1', 'normalized_antiB_g1'] = (data.loc[data['Eqwidth_bin'] == 'b1', 'ANTI_B'] -  data.loc[data['Eqwidth_bin'] == 'b1', 'ANTI_B'].min())/ (data.loc[data['Eqwidth_bin'] == 'b1', 'ANTI_B'].max()-data.loc[data['Eqwidth_bin'] == 'b1', 'ANTI_B'].min())

# %%
data['normalized_antiB_g1']
# Out:
# 0     1.000000
# 1     0.157513
# 2     0.124352
# 3     0.000000
# 4     0.556477
# 5     0.961658
# 6     0.679793
# 7     0.417617
# 8     0.218653
# 9     0.393782
# 10    0.621762
# 11    0.801036
# 12    0.144041
# 13    0.950259
# 14    0.894301
# 15    0.864249
# 16    0.153368
# 17    0.196891
# 18    0.033161
# 19    0.483938
# 20    0.877720
# 21    0.528497
# 22    0.118135
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# Name: normalized_antiB_g1, dtype: float64

# %%
data.loc[data['Eqwidth_bin'] == 'b5', 'normalized_antiA_g2'] = (data.loc[data['Eqwidth_bin'] == 'b5', 'ANTI_A'] -  data.loc[data['Eqwidth_bin'] == 'b5', 'ANTI_A'].min())/ (data.loc[data['Eqwidth_bin'] == 'b5', 'ANTI_A'].max()-data.loc[data['Eqwidth_bin'] == 'b5', 'ANTI_A'].min())
data.loc[data['Eqwidth_bin'] == 'b5', 'normalized_antiB_g2'] = (data.loc[data['Eqwidth_bin'] == 'b5', 'ANTI_B'] -  data.loc[data['Eqwidth_bin'] == 'b5', 'ANTI_B'].min())/ (data.loc[data['Eqwidth_bin'] == 'b5', 'ANTI_B'].max()-data.loc[data['Eqwidth_bin'] == 'b5', 'ANTI_B'].min())

# %%
data['normalized_antiA_g2']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32    0.835220
# 33    0.817610
# 34    0.291824
# 35    0.272956
# 36    0.000000
# 37    1.000000
# 38    0.851572
# 39    0.822642
# Name: normalized_antiA_g2, dtype: float64

# %%
data['normalized_antiB_g2']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32    0.549107
# 33    0.867188
# 34    0.127232
# 35    0.272321
# 36    0.000000
# 37    0.777902
# 38    1.000000
# 39    0.879464
# Name: normalized_antiB_g2, dtype: float64

# %%
plt.scatter(data['normalized_antiB_g1'], data['normalized_antiA_g1'])
plt.title('Scatter_G1')
plt.ylabel('normalized_antiA_g1')
plt.xlabel('normalized_antiB_g1')
plt.show()

# %%
plt.scatter(data['normalized_antiB_g2'], data['normalized_antiA_g2'])
plt.title('Scatter_G2')
plt.ylabel('normalized_antiA_g2')
plt.xlabel('normalized_antiB_g2')
plt.show()

# %%
corr_g1 = data['normalized_antiA_g1'].corr(data['normalized_antiB_g1'])
corr_g1
# Out:
# -0.44962747254599306

# %%
corr_g2 = data['normalized_antiA_g2'].corr(data['normalized_antiB_g2'])
corr_g2
# Out:
# 0.9170418327249674
