# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('EduData.csv')

# %%
data
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID
# 0        M          KW       KuwaIT    lowerlevel    G-04         A  \
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation raisedhands  VisITedResources
# 0           IT        F   Father          15                16  \
# ...

# %%
data.describe()
# Out:
#        VisITedResources  AnnouncementsView  Discussion
# count        480.000000         480.000000  480.000000
# mean          54.797917          37.918750   43.283333
# std           33.080007          26.611244   27.637735
# min            0.000000           0.000000    1.000000
# 25%           20.000000          14.000000   20.000000
# 50%           65.000000          33.000000   39.000000
# 75%           84.000000          58.000000   70.000000
# max           99.000000          98.000000   99.000000

# %%
data = data.replace("?", np.NaN)
data.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT  \
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation raisedhands  VisITedResources  AnnouncementsView
# 0        F   Father          15                16                  2  \
# 1        F   Father          20                20                  3
# 2        F   Father          10                 7                  0
# 3        F   Father          30                25                  5
# 4        F   Father          40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction
# 0          20                   Yes                     Good  \
# ...

# %%
data.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     2
# SectionID                   0
# Topic                       2
# Semester                    0
# Relation                    8
# raisedhands                 2
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
data.dtypes
# Out:
# gender                      object
# NationalITy                 object
# PlaceofBirth                object
# StageID                     object
# GradeID                     object
# SectionID                   object
# Topic                       object
# Semester                    object
# Relation                    object
# raisedhands                 object
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentAnsweringSurvey       object
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
data["Topic"].value_counts()
# Out:
# Topic
# IT           94
# French       65
# Arabic       58
# Science      51
# English      45
# Biology      30
# Spanish      25
# Chemistry    24
# Geology      24
# Quran        22
# Math         21
# History      19
# Name: count, dtype: int64

# %%
data['Topic'].replace(np.NaN, 'IT', inplace=True)

# %%
data['Topic'].isnull().sum()
# Out:
# 0

# %%
data = data.dropna(subset = ['Relation','GradeID'])

# %%
data.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 2
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
avg = data['raisedhands'].astype('float').mean()
avg
# Out:
# 46.83119658119658

# %%
data["raisedhands"].replace(np.NaN, 46, inplace=True)

# %%
data.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
data['Semester'].value_counts()
# Out:
# Semester
# F    240
# S    228
# T      2
# Name: count, dtype: int64

# %%
data = data[data['Semester'].str.contains("T") == False]

# %%
data.reset_index(drop = True, inplace = True)

# %%
data
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID
# 0        M          KW       KuwaIT    lowerlevel    G-04         A  \
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 463      F      Jordan       Jordan  MiddleSchool    G-08         A
# 464      F      Jordan       Jordan  MiddleSchool    G-08         A
# 465      F      Jordan       Jordan  MiddleSchool    G-08         A
# 466      F      Jordan       Jordan  MiddleSchool    G-08         A
# 467      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation raisedhands  VisITedResources
# 0           IT        F   Father          15                16  \
# ...

# %%
data.drop(['ParentAnsweringSurvey'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT  \
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation raisedhands  VisITedResources  AnnouncementsView
# 0        F   Father          15                16                  2  \
# 1        F   Father          20                20                  3
# 2        F   Father          10                 7                  0
# 3        F   Father          30                25                  5
# 4        F   Father          40                50                 12
#
#    Discussion ParentschoolSatisfaction StudentAbsenceDays Class
# 0          20                     Good            Under-7     M
# ...

# %%
data.dtypes
# Out:
# gender                      object
# NationalITy                 object
# PlaceofBirth                object
# StageID                     object
# GradeID                     object
# SectionID                   object
# Topic                       object
# Semester                    object
# Relation                    object
# raisedhands                 object
# VisITedResources             int64
# AnnouncementsView            int64
# Discussion                   int64
# ParentschoolSatisfaction    object
# StudentAbsenceDays          object
# Class                       object
# dtype: object

# %%
data['raisedhands'] =  data['raisedhands'].astype('float') / data['raisedhands'].astype('float').max()

# %%
data['VisITedResources'] =  data['VisITedResources'] / data['VisITedResources'].astype('float').max()

# %%
data.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT  \
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView
# 0        F   Father         0.15          0.161616                  2  \
# 1        F   Father         0.20          0.202020                  3
# 2        F   Father         0.10          0.070707                  0
# 3        F   Father         0.30          0.252525                  5
# 4        F   Father         0.40          0.505051                 12
#
#    Discussion ParentschoolSatisfaction StudentAbsenceDays Class
# ...

# %%
data['GradeID'].value_counts()
# Out:
# GradeID
# G-02    142
# G-08    115
# G-07     98
# G-04     48
# G-06     31
# G-11     13
# G-12      9
# G-09      5
# G-10      4
# G-05      3
# Name: count, dtype: int64

# %%
data['GradeID'].replace("G-02", 1, inplace = True)
data['GradeID'].replace("G-04", 2, inplace = True)
data['GradeID'].replace("G-05", 3, inplace = True)
data['GradeID'].replace("G-06", 4, inplace = True)
data['GradeID'].replace("G-07", 5, inplace = True)
data['GradeID'].replace("G-08", 6, inplace = True)
data['GradeID'].replace("G-09", 7, inplace = True)
data['GradeID'].replace("G-10", 8, inplace = True)
data['GradeID'].replace("G-11", 9, inplace = True)
data['GradeID'].replace("G-12", 10, inplace = True)

# %%
data['StudentAbsenceDays'].value_counts()
# Out:
# StudentAbsenceDays
# Under-7    282
# Above-7    186
# Name: count, dtype: int64

# %%
data['StudentAbsenceDays'].replace("Under-7", 0, inplace = True)
data['StudentAbsenceDays'].replace("Above-7", 1, inplace = True)

# %%
bins = np.linspace(min(data['Discussion']), max(data['Discussion']), 4)
bins
# Out:
# array([ 1.        , 33.66666667, 66.33333333, 99.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
data['Discussion-Binned'] = pd.cut(data['Discussion'], bins, labels = group_names, include_lowest = True)

# %%
data[['Discussion','Discussion-Binned']].head()
# Out:
#    Discussion Discussion-Binned
# 0          20               Low
# 1          25               Low
# 2          30               Low
# 3          35            Medium
# 4          50            Medium

# %%
data.to_csv("DW2.csv")
